# %%
import pandas as pd

# %%
characters = pd.read_csv(r'C:\Users\DVILA\Downloads\hp-dashboard\hp-dashboard\soudatadrivendata\Characters.csv', sep=',', encoding='latin1')

characters
# Out:
#      Character ID    Character Name                Species  Gender  \
# 0               1      Harry Potter                  Human    Male
# 1               2       Ron Weasley                  Human    Male
# 2               3  Hermione Granger                  Human  Female
# 3               4  Albus Dumbledore                  Human    Male
# 4               5     Rubeus Hagrid  Half-Human/Half-Giant    Male
# ..            ...               ...                    ...     ...
# 161           162            Waiter                    NaN     NaN
# 162           163             Boy 2                    NaN     NaN
# 163           164             Crowd                    NaN     NaN
# 164           165       Gryffindors                    NaN     NaN
# 165           166        Professors                    NaN     NaN
#
#           House              Patronus Wand (Wood)         Wand (Core)
# 0    Gryffindor                  Stag       Holly     Phoenix Feather
# ...

# %%
# For para puxar imagens do meu github em uma nova coluna
urls = []


for i in range(1, 167):
    url = f"https://raw.githubusercontent.com/viladavi6/hp-dashboard/refs/heads/master/images/characters/{i}.png"
    urls.append(url)


characters['Url'] = urls

# %%
characters
# Out:
#      Character ID    Character Name                Species  Gender  \
# 0               1      Harry Potter                  Human    Male
# 1               2       Ron Weasley                  Human    Male
# 2               3  Hermione Granger                  Human  Female
# 3               4  Albus Dumbledore                  Human    Male
# 4               5     Rubeus Hagrid  Half-Human/Half-Giant    Male
# ..            ...               ...                    ...     ...
# 161           162            Waiter                    NaN     NaN
# 162           163             Boy 2                    NaN     NaN
# 163           164             Crowd                    NaN     NaN
# 164           165       Gryffindors                    NaN     NaN
# 165           166        Professors                    NaN     NaN
#
#           House              Patronus Wand (Wood)         Wand (Core)  \
# 0    Gryffindor                  Stag       Holly     Phoenix Feather
# ...

# %%
# Adicionando nova linha para imagem genérica
new_values = [0, '', '', '', '', '', '', '', 'https://raw.githubusercontent.com/viladavi6/hp-dashboard/refs/heads/master/images/characters/0.png']


characters.loc[len(characters)] = new_values

characters['House'] = characters['House'].replace('Beauxbatons Academy of Magic', 'Beauxbatons')

characters
# Out:
#      Character ID    Character Name                Species  Gender  \
# 0               1      Harry Potter                  Human    Male
# 1               2       Ron Weasley                  Human    Male
# 2               3  Hermione Granger                  Human  Female
# 3               4  Albus Dumbledore                  Human    Male
# 4               5     Rubeus Hagrid  Half-Human/Half-Giant    Male
# ..            ...               ...                    ...     ...
# 162           163             Boy 2                    NaN     NaN
# 163           164             Crowd                    NaN     NaN
# 164           165       Gryffindors                    NaN     NaN
# 165           166        Professors                    NaN     NaN
# 166             0
#
#           House              Patronus Wand (Wood)         Wand (Core)  \
# 0    Gryffindor                  Stag       Holly     Phoenix Feather
# ...

# %%
# Salvando
output_path = r'C:\Users\DVILA\Downloads\hp-dashboard\hp-dashboard\data\Characters.xlsx'


characters.to_excel(output_path, index=False, engine='openpyxl', sheet_name='characters')
